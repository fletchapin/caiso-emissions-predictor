# %%
import os
import pandas as pd
import tensorflow as tf
import numpy as np
import math
import statistics
import time
import h5py
import matplotlib.pyplot as plt
from tensorflow.python.framework import ops
from tensorflow import keras
from keras.layers import Layer
import keras.backend as K

import plotly 
import plotly.express as px
import plotly.graph_objects as go

# %%
from google.colab import drive
drive.mount('/content/drive')

# Navigate to CS 230 Project folder. This might have a different path depending on user
os.chdir("/content/drive/MyDrive/CS 230 Project/Data")
# Out:
# Mounted at /content/drive

# %%
# Following this example: https://keras.io/examples/timeseries/timeseries_weather_forecasting/
def normalize(data, train_split):
    data_mean = data[:train_split].mean(axis=0)
    data_std = data[:train_split].std(axis=0)
    return (data - data_mean) / data_std

# %%
def create_model(input_data, design, dataset_train):
    for batch in dataset_train.take(1):
        inputs, targets = batch
    if design == "24-neuron LSTM":
        inputs = keras.layers.Input(shape=(inputs.shape[1], inputs.shape[2]))
        lstm_out = keras.layers.LSTM(
            24,
            kernel_regularizer=keras.regularizers.l1(0.00001),
            activation="tanh"
        )(inputs)
        outputs = keras.layers.Dense(1)(lstm_out)

        model = keras.Model(inputs=inputs, outputs=outputs)
        model.compile(
          optimizer=keras.optimizers.Adam(learning_rate=0.000001),
          loss="huber",
          metrics=[
            keras.metrics.MeanAbsoluteError(name='abs'),
            keras.metrics.RootMeanSquaredError(name='rmse')
          ]
        )
    elif design == "48-neuron GRU":
        inputs = keras.layers.Input(shape=(inputs.shape[1], inputs.shape[2]))
        dropout = keras.layers.Dropout(0.8)(inputs)
        gru_out = keras.layers.GRU(48, activation="tanh")(dropout)
        outputs = keras.layers.Dense(1)(gru_out)
        
        model = keras.Model(inputs=inputs, outputs=outputs)
        model.compile(
          optimizer=keras.optimizers.Adam(learning_rate=0.001),
          loss="mae",
          metrics=[
            keras.metrics.MeanAbsoluteError(name='abs'),
            keras.metrics.RootMeanSquaredError(name='rmse')
          ]
        )
    elif design == "72-layer LSTM":
        inputs = keras.layers.Input(shape=(inputs.shape[1], inputs.shape[2]))
        dropout = keras.layers.Dropout(0.8)(inputs)
        lstm_out = keras.layers.LSTM(72, activation="tanh")(dropout)
        outputs = keras.layers.Dense(1)(lstm_out)
        
        model = keras.Model(inputs=inputs, outputs=outputs)
        model.compile(
          optimizer=keras.optimizers.Adam(learning_rate=0.01),
          loss="huber",
          metrics=[
            keras.metrics.MeanAbsoluteError(name='abs'),
            keras.metrics.RootMeanSquaredError(name='rmse')
          ]
        )
    return model

# %%
def select_input_data(i, j):
    if j == 0:
        if i == 0:
            df = pd.read_csv("merged_data_normalized_v2.csv").fillna(0)
        elif i == 1:
            df = pd.read_csv("merged_data_v2.csv").fillna(0)
    elif j == 1:
        if i == 0:
            df = pd.read_csv("merged_data_normalized.csv").fillna(0)
        elif i == 1:
            df = pd.read_csv("merged_data.csv").fillna(0)
    elif j == 2:
        if i == 0:
            df = pd.read_csv("eia_data_normalized.csv").fillna(0)
        elif i == 1:
            df = pd.read_csv("eia_data.csv").fillna(0)

    return df

# %%
def split_training_data(df, i, h):
  dev_split_idx = df[df["DateTime"] == "5/1/2021 0:00"].index.tolist()[0]
  test_split_idx = df[df["DateTime"] == "11/1/2021 0:00"].index.tolist()[0]
  features = df.drop([x for x in df.columns if "Soil Temp" in x], axis=1)
  features["DateTime"] = pd.to_datetime(features["DateTime"])
  features.set_index("DateTime", inplace=True)
  if i == 1:
      features = normalize(features, dev_split_idx)

  # Save hour, month, and weekday as features
  features["hour"] = features.index.hour
  features["month"] = features.index.month
  features["weekday"] = features.index.weekday

  train_data = features.iloc[0:dev_split_idx]
  dev_data = features.iloc[dev_split_idx:test_split_idx]
  test_data = features.iloc[test_split_idx:]

  # Pin these hyperparameters
  past = 72
  future = 24
  batch_size = 256

  start = past + future
  end = start + dev_split_idx

  X_train = train_data.values
  Y_train = features.iloc[start:end, h]

  dataset_train = keras.preprocessing.timeseries_dataset_from_array(
      X_train,
      Y_train,
      sequence_length=72, # use 72 hours of historical data
      sampling_rate=1, # make a prediction every 6 hours
      batch_size=batch_size,
  )

  end_dev = start + test_split_idx
  x_end = len(test_data) - past - future

  x_test = test_data.iloc[:x_end].values
  y_test = features.iloc[end_dev:, h]

  dataset_test = keras.preprocessing.timeseries_dataset_from_array(
      x_test,
      y_test,
      sequence_length=72, # use 72 hours of historical data
      sampling_rate=1, # make a prediction every 6 hours
      batch_size=batch_size,
  )

  return dataset_train, dataset_test

# %%
designs = ["24-neuron LSTM", "48-neuron GRU", "72-layer LSTM"]
rmse_arr = np.zeros((2, 3, 3, 8))

# %%
for i in range(2):
  for j in range(3):
    for k in range(3):
      for h in range(8):
        path_checkpoint = "TrainedModels/model_checkpoint_" + str(i) + "_" + str(j) + "_" + str(k) + "_" + str(h) + ".h5"
        df = select_input_data(i, j)
        dataset_train, dataset_test = split_training_data(df, i, h)
        model = create_model(df, designs[k], dataset_train)
        model.load_weights(path_checkpoint)
        model.summary()
        # Prediction on validation set
        test_prediction = []
        test_true_result = []
        for x, y in dataset_test.__iter__():
          test_prediction.append(model.predict(x))
          test_true_result.append(y)

        test_prediction = np.array([item for sublist in test_prediction for item in sublist])
        test_true_result = np.array([item for sublist in test_true_result for item in sublist])

        rmse = np.sqrt(np.mean((test_prediction-test_true_result)**2))
        print("RMSE for model_" + str(i) + "_" + str(j) + "_" + str(k) + "_" + str(h) + " is " + str(rmse))
        rmse_arr[i, j, k, h] = rmse

np.save("rmse_results_.npy", rmse_arr)
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 72, 67)]          0
#
#  lstm_4 (LSTM)               (None, 24)                8832
#
#  dense_4 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 8,857
# Trainable params: 8,857
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_0_0 is 0.7944775270749501
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 72, 67)]          0
#
#  lstm_5 (LSTM)               (None, 24)                8832
#
#  dense_5 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 8,857
# Trainable params: 8,857
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_0_1 is 0.44762023442481075
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 72, 67)]          0
#
#  lstm_6 (LSTM)               (None, 24)                8832
#
#  dense_6 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 8,857
# Trainable params: 8,857
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_0_2 is 0.5188996240429508
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 72, 67)]          0
#
#  lstm_7 (LSTM)               (None, 24)                8832
#
#  dense_7 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 8,857
# Trainable params: 8,857
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_0_3 is 0.49919553919973947
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 72, 67)]          0
#
#  lstm_8 (LSTM)               (None, 24)                8832
#
#  dense_8 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 8,857
# Trainable params: 8,857
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_0_4 is 0.7082527096981299
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 72, 67)]          0
#
#  lstm_9 (LSTM)               (None, 24)                8832
#
#  dense_9 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 8,857
# Trainable params: 8,857
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_0_5 is 0.23253068354135029
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 72, 67)]          0
#
#  lstm_10 (LSTM)              (None, 24)                8832
#
#  dense_10 (Dense)            (None, 1)                 25
#
# =================================================================
# Total params: 8,857
# Trainable params: 8,857
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_0_6 is 0.5020772114677264
# Model: "model_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 72, 67)]          0
#
#  lstm_11 (LSTM)              (None, 24)                8832
#
#  dense_11 (Dense)            (None, 1)                 25
#
# =================================================================
# Total params: 8,857
# Trainable params: 8,857
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_0_7 is 0.8792025574896148
# Model: "model_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_13 (InputLayer)       [(None, 72, 67)]          0
#
#  dropout (Dropout)           (None, 72, 67)            0
#
#  gru (GRU)                   (None, 48)                16848
#
#  dense_12 (Dense)            (None, 1)                 49
#
# =================================================================
# Total params: 16,897
# Trainable params: 16,897
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_1_0 is 0.0007111616371264306
# Model: "model_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_14 (InputLayer)       [(None, 72, 67)]          0
#
#  dropout_1 (Dropout)         (None, 72, 67)            0
#
#  gru_1 (GRU)                 (None, 48)                16848
#
#  dense_13 (Dense)            (None, 1)                 49
#
# =================================================================
# Total params: 16,897
# Trainable params: 16,897
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_1_1 is 0.08931745575673829
# Model: "model_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_15 (InputLayer)       [(None, 72, 67)]          0
#
#  dropout_2 (Dropout)         (None, 72, 67)            0
#
#  gru_2 (GRU)                 (None, 48)                16848
#
#  dense_14 (Dense)            (None, 1)                 49
#
# =================================================================
# Total params: 16,897
# Trainable params: 16,897
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_1_2 is 0.20207503220511
# Model: "model_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_16 (InputLayer)       [(None, 72, 67)]          0
#
#  dropout_3 (Dropout)         (None, 72, 67)            0
#
#  gru_3 (GRU)                 (None, 48)                16848
#
#  dense_15 (Dense)            (None, 1)                 49
#
# =================================================================
# Total params: 16,897
# Trainable params: 16,897
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_1_3 is 0.04017449974462984
# Model: "model_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_17 (InputLayer)       [(None, 72, 67)]          0
#
#  dropout_4 (Dropout)         (None, 72, 67)            0
#
#  gru_4 (GRU)                 (None, 48)                16848
#
#  dense_16 (Dense)            (None, 1)                 49
#
# =================================================================
# Total params: 16,897
# Trainable params: 16,897
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_1_4 is 0.10017566934399232
# Model: "model_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_18 (InputLayer)       [(None, 72, 67)]          0
#
#  dropout_5 (Dropout)         (None, 72, 67)            0
#
#  gru_5 (GRU)                 (None, 48)                16848
#
#  dense_17 (Dense)            (None, 1)                 49
#
# =================================================================
# Total params: 16,897
# Trainable params: 16,897
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_1_5 is 0.002055830539560919
# Model: "model_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_19 (InputLayer)       [(None, 72, 67)]          0
#
#  dropout_6 (Dropout)         (None, 72, 67)            0
#
#  gru_6 (GRU)                 (None, 48)                16848
#
#  dense_18 (Dense)            (None, 1)                 49
#
# =================================================================
# Total params: 16,897
# Trainable params: 16,897
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_1_6 is 0.29958658645645625
# Model: "model_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, 72, 67)]          0
#
#  dropout_7 (Dropout)         (None, 72, 67)            0
#
#  gru_7 (GRU)                 (None, 48)                16848
#
#  dense_19 (Dense)            (None, 1)                 49
#
# =================================================================
# Total params: 16,897
# Trainable params: 16,897
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_1_7 is 0.12286964647877432
# Model: "model_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_21 (InputLayer)       [(None, 72, 67)]          0
#
#  dropout_8 (Dropout)         (None, 72, 67)            0
#
#  lstm_12 (LSTM)              (None, 72)                40320
#
#  dense_20 (Dense)            (None, 1)                 73
#
# =================================================================
# Total params: 40,393
# Trainable params: 40,393
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_2_0 is 0.00037109859058392165
# Model: "model_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_22 (InputLayer)       [(None, 72, 67)]          0
#
#  dropout_9 (Dropout)         (None, 72, 67)            0
#
#  lstm_13 (LSTM)              (None, 72)                40320
#
#  dense_21 (Dense)            (None, 1)                 73
#
# =================================================================
# Total params: 40,393
# Trainable params: 40,393
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_2_1 is 0.04747194031830888
# Model: "model_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_23 (InputLayer)       [(None, 72, 67)]          0
#
#  dropout_10 (Dropout)        (None, 72, 67)            0
#
#  lstm_14 (LSTM)              (None, 72)                40320
#
#  dense_22 (Dense)            (None, 1)                 73
#
# =================================================================
# Total params: 40,393
# Trainable params: 40,393
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_2_2 is 0.1727751808276007
# Model: "model_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_24 (InputLayer)       [(None, 72, 67)]          0
#
#  dropout_11 (Dropout)        (None, 72, 67)            0
#
#  lstm_15 (LSTM)              (None, 72)                40320
#
#  dense_23 (Dense)            (None, 1)                 73
#
# =================================================================
# Total params: 40,393
# Trainable params: 40,393
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_2_3 is 0.048716366801899856
# Model: "model_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_25 (InputLayer)       [(None, 72, 67)]          0
#
#  dropout_12 (Dropout)        (None, 72, 67)            0
#
#  lstm_16 (LSTM)              (None, 72)                40320
#
#  dense_24 (Dense)            (None, 1)                 73
#
# =================================================================
# Total params: 40,393
# Trainable params: 40,393
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_2_4 is 0.0719697698864669
# Model: "model_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_26 (InputLayer)       [(None, 72, 67)]          0
#
#  dropout_13 (Dropout)        (None, 72, 67)            0
#
#  lstm_17 (LSTM)              (None, 72)                40320
#
#  dense_25 (Dense)            (None, 1)                 73
#
# =================================================================
# Total params: 40,393
# Trainable params: 40,393
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_2_5 is 0.0018378596711337613
# Model: "model_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_27 (InputLayer)       [(None, 72, 67)]          0
#
#  dropout_14 (Dropout)        (None, 72, 67)            0
#
#  lstm_18 (LSTM)              (None, 72)                40320
#
#  dense_26 (Dense)            (None, 1)                 73
#
# =================================================================
# Total params: 40,393
# Trainable params: 40,393
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_2_6 is 0.2726719150316641
# Model: "model_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_28 (InputLayer)       [(None, 72, 67)]          0
#
#  dropout_15 (Dropout)        (None, 72, 67)            0
#
#  lstm_19 (LSTM)              (None, 72)                40320
#
#  dense_27 (Dense)            (None, 1)                 73
#
# =================================================================
# Total params: 40,393
# Trainable params: 40,393
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_2_7 is 0.09472947178110515
# Model: "model_28"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_29 (InputLayer)       [(None, 72, 19)]          0
#
#  lstm_20 (LSTM)              (None, 24)                4224
#
#  dense_28 (Dense)            (None, 1)                 25
#
# =================================================================
# Total params: 4,249
# Trainable params: 4,249
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_0_0 is 0.7039142108378462
# Model: "model_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_30 (InputLayer)       [(None, 72, 19)]          0
#
#  lstm_21 (LSTM)              (None, 24)                4224
#
#  dense_29 (Dense)            (None, 1)                 25
#
# =================================================================
# Total params: 4,249
# Trainable params: 4,249
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_0_1 is 0.5900189506411508
# Model: "model_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_31 (InputLayer)       [(None, 72, 19)]          0
#
#  lstm_22 (LSTM)              (None, 24)                4224
#
#  dense_30 (Dense)            (None, 1)                 25
#
# =================================================================
# Total params: 4,249
# Trainable params: 4,249
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_0_2 is 0.8495091157797572
# Model: "model_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_32 (InputLayer)       [(None, 72, 19)]          0
#
#  lstm_23 (LSTM)              (None, 24)                4224
#
#  dense_31 (Dense)            (None, 1)                 25
#
# =================================================================
# Total params: 4,249
# Trainable params: 4,249
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_0_3 is 0.282001590249873
# Model: "model_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_33 (InputLayer)       [(None, 72, 19)]          0
#
#  lstm_24 (LSTM)              (None, 24)                4224
#
#  dense_32 (Dense)            (None, 1)                 25
#
# =================================================================
# Total params: 4,249
# Trainable params: 4,249
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_0_4 is 0.3325276779912057
# Model: "model_33"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_34 (InputLayer)       [(None, 72, 19)]          0
#
#  lstm_25 (LSTM)              (None, 24)                4224
#
#  dense_33 (Dense)            (None, 1)                 25
#
# =================================================================
# Total params: 4,249
# Trainable params: 4,249
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_0_5 is 0.40110092103904843
# Model: "model_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_35 (InputLayer)       [(None, 72, 19)]          0
#
#  lstm_26 (LSTM)              (None, 24)                4224
#
#  dense_34 (Dense)            (None, 1)                 25
#
# =================================================================
# Total params: 4,249
# Trainable params: 4,249
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_0_6 is 0.7030911005484577
# Model: "model_35"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_36 (InputLayer)       [(None, 72, 19)]          0
#
#  lstm_27 (LSTM)              (None, 24)                4224
#
#  dense_35 (Dense)            (None, 1)                 25
#
# =================================================================
# Total params: 4,249
# Trainable params: 4,249
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_0_7 is 0.2848175730995725
# Model: "model_36"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_37 (InputLayer)       [(None, 72, 19)]          0
#
#  dropout_16 (Dropout)        (None, 72, 19)            0
#
#  gru_8 (GRU)                 (None, 48)                9936
#
#  dense_36 (Dense)            (None, 1)                 49
#
# =================================================================
# Total params: 9,985
# Trainable params: 9,985
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_1_0 is 0.34427087547258184
# Model: "model_37"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_38 (InputLayer)       [(None, 72, 19)]          0
#
#  dropout_17 (Dropout)        (None, 72, 19)            0
#
#  gru_9 (GRU)                 (None, 48)                9936
#
#  dense_37 (Dense)            (None, 1)                 49
#
# =================================================================
# Total params: 9,985
# Trainable params: 9,985
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_1_1 is 0.08862917121550203
# Model: "model_38"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_39 (InputLayer)       [(None, 72, 19)]          0
#
#  dropout_18 (Dropout)        (None, 72, 19)            0
#
#  gru_10 (GRU)                (None, 48)                9936
#
#  dense_38 (Dense)            (None, 1)                 49
#
# =================================================================
# Total params: 9,985
# Trainable params: 9,985
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_1_2 is 0.20455607214237898
# Model: "model_39"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_40 (InputLayer)       [(None, 72, 19)]          0
#
#  dropout_19 (Dropout)        (None, 72, 19)            0
#
#  gru_11 (GRU)                (None, 48)                9936
#
#  dense_39 (Dense)            (None, 1)                 49
#
# =================================================================
# Total params: 9,985
# Trainable params: 9,985
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_1_3 is 0.16424882598071197
# Model: "model_40"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_41 (InputLayer)       [(None, 72, 19)]          0
#
#  dropout_20 (Dropout)        (None, 72, 19)            0
#
#  gru_12 (GRU)                (None, 48)                9936
#
#  dense_40 (Dense)            (None, 1)                 49
#
# =================================================================
# Total params: 9,985
# Trainable params: 9,985
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_1_4 is 0.11619163369726795
# Model: "model_41"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_42 (InputLayer)       [(None, 72, 19)]          0
#
#  dropout_21 (Dropout)        (None, 72, 19)            0
#
#  gru_13 (GRU)                (None, 48)                9936
#
#  dense_41 (Dense)            (None, 1)                 49
#
# =================================================================
# Total params: 9,985
# Trainable params: 9,985
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_1_5 is 0.2252700133988612
# Model: "model_42"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_43 (InputLayer)       [(None, 72, 19)]          0
#
#  dropout_22 (Dropout)        (None, 72, 19)            0
#
#  gru_14 (GRU)                (None, 48)                9936
#
#  dense_42 (Dense)            (None, 1)                 49
#
# =================================================================
# Total params: 9,985
# Trainable params: 9,985
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_1_6 is 0.2858680201658539
# Model: "model_43"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_44 (InputLayer)       [(None, 72, 19)]          0
#
#  dropout_23 (Dropout)        (None, 72, 19)            0
#
#  gru_15 (GRU)                (None, 48)                9936
#
#  dense_43 (Dense)            (None, 1)                 49
#
# =================================================================
# Total params: 9,985
# Trainable params: 9,985
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_1_7 is 0.44204279196272916
# Model: "model_44"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_45 (InputLayer)       [(None, 72, 19)]          0
#
#  dropout_24 (Dropout)        (None, 72, 19)            0
#
#  lstm_28 (LSTM)              (None, 72)                26496
#
#  dense_44 (Dense)            (None, 1)                 73
#
# =================================================================
# Total params: 26,569
# Trainable params: 26,569
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_2_0 is 0.0007301418009307564
# Model: "model_45"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_46 (InputLayer)       [(None, 72, 19)]          0
#
#  dropout_25 (Dropout)        (None, 72, 19)            0
#
#  lstm_29 (LSTM)              (None, 72)                26496
#
#  dense_45 (Dense)            (None, 1)                 73
#
# =================================================================
# Total params: 26,569
# Trainable params: 26,569
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_2_1 is 0.052901319875131504
# Model: "model_46"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_47 (InputLayer)       [(None, 72, 19)]          0
#
#  dropout_26 (Dropout)        (None, 72, 19)            0
#
#  lstm_30 (LSTM)              (None, 72)                26496
#
#  dense_46 (Dense)            (None, 1)                 73
#
# =================================================================
# Total params: 26,569
# Trainable params: 26,569
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_2_2 is 0.18371947126116014
# Model: "model_47"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_48 (InputLayer)       [(None, 72, 19)]          0
#
#  dropout_27 (Dropout)        (None, 72, 19)            0
#
#  lstm_31 (LSTM)              (None, 72)                26496
#
#  dense_47 (Dense)            (None, 1)                 73
#
# =================================================================
# Total params: 26,569
# Trainable params: 26,569
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_2_3 is 0.05179037804397211
# Model: "model_48"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_49 (InputLayer)       [(None, 72, 19)]          0
#
#  dropout_28 (Dropout)        (None, 72, 19)            0
#
#  lstm_32 (LSTM)              (None, 72)                26496
#
#  dense_48 (Dense)            (None, 1)                 73
#
# =================================================================
# Total params: 26,569
# Trainable params: 26,569
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_2_4 is 0.07716354675313242
# Model: "model_49"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_50 (InputLayer)       [(None, 72, 19)]          0
#
#  dropout_29 (Dropout)        (None, 72, 19)            0
#
#  lstm_33 (LSTM)              (None, 72)                26496
#
#  dense_49 (Dense)            (None, 1)                 73
#
# =================================================================
# Total params: 26,569
# Trainable params: 26,569
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_2_5 is 0.0024929749211445433
# Model: "model_50"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_51 (InputLayer)       [(None, 72, 19)]          0
#
#  dropout_30 (Dropout)        (None, 72, 19)            0
#
#  lstm_34 (LSTM)              (None, 72)                26496
#
#  dense_50 (Dense)            (None, 1)                 73
#
# =================================================================
# Total params: 26,569
# Trainable params: 26,569
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_2_6 is 0.2650139820525122
# Model: "model_51"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_52 (InputLayer)       [(None, 72, 19)]          0
#
#  dropout_31 (Dropout)        (None, 72, 19)            0
#
#  lstm_35 (LSTM)              (None, 72)                26496
#
#  dense_51 (Dense)            (None, 1)                 73
#
# =================================================================
# Total params: 26,569
# Trainable params: 26,569
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_2_7 is 0.099480994224914
# Model: "model_52"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_53 (InputLayer)       [(None, 72, 11)]          0
#
#  lstm_36 (LSTM)              (None, 24)                3456
#
#  dense_52 (Dense)            (None, 1)                 25
#
# =================================================================
# Total params: 3,481
# Trainable params: 3,481
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_2_0_0 is 0.3485092556358162
# Model: "model_53"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_54 (InputLayer)       [(None, 72, 11)]          0
#
#  lstm_37 (LSTM)              (None, 24)                3456
#
#  dense_53 (Dense)            (None, 1)                 25
#
# =================================================================
# Total params: 3,481
# Trainable params: 3,481
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_2_0_1 is 0.17346769513027507
# Model: "model_54"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_55 (InputLayer)       [(None, 72, 11)]          0
#
#  lstm_38 (LSTM)              (None, 24)                3456
#
#  dense_54 (Dense)            (None, 1)                 25
#
# =================================================================
# Total params: 3,481
# Trainable params: 3,481
# Non-trainable params: 0
# _________________________________________________________________
# ...
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_1_2_0_7 is 1.1135809664117333
# Model: "model_132"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_133 (InputLayer)      [(None, 72, 13)]          0
#
#  dropout_80 (Dropout)        (None, 72, 13)            0
#
#  gru_40 (GRU)                (None, 48)                9072
#
#  dense_132 (Dense)           (None, 1)                 49
#
# =================================================================
# Total params: 9,121
# Trainable params: 9,121
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_1_2_1_0 is 1.1702313317171908
# Model: "model_133"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_134 (InputLayer)      [(None, 72, 13)]          0
#
#  dropout_81 (Dropout)        (None, 72, 13)            0
#
#  gru_41 (GRU)                (None, 48)                9072
#
#  dense_133 (Dense)           (None, 1)                 49
#
# =================================================================
# Total params: 9,121
# Trainable params: 9,121
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_1_2_1_1 is 0.4313838126399138
# Model: "model_134"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_135 (InputLayer)      [(None, 72, 13)]          0
#
#  dropout_82 (Dropout)        (None, 72, 13)            0
#
#  gru_42 (GRU)                (None, 48)                9072
#
#  dense_134 (Dense)           (None, 1)                 49
#
# =================================================================
# Total params: 9,121
# Trainable params: 9,121
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_1_2_1_2 is 0.8071895168970192
# Model: "model_135"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_136 (InputLayer)      [(None, 72, 13)]          0
#
#  dropout_83 (Dropout)        (None, 72, 13)            0
#
#  gru_43 (GRU)                (None, 48)                9072
#
#  dense_135 (Dense)           (None, 1)                 49
#
# =================================================================
# Total params: 9,121
# Trainable params: 9,121
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_1_2_1_3 is 0.7537662145557198
# Model: "model_136"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_137 (InputLayer)      [(None, 72, 13)]          0
#
#  dropout_84 (Dropout)        (None, 72, 13)            0
#
#  gru_44 (GRU)                (None, 48)                9072
#
#  dense_136 (Dense)           (None, 1)                 49
#
# =================================================================
# Total params: 9,121
# Trainable params: 9,121
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_1_2_1_4 is 10.404885557284235
# Model: "model_137"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_138 (InputLayer)      [(None, 72, 13)]          0
#
#  dropout_85 (Dropout)        (None, 72, 13)            0
#
#  gru_45 (GRU)                (None, 48)                9072
#
#  dense_137 (Dense)           (None, 1)                 49
#
# =================================================================
# Total params: 9,121
# Trainable params: 9,121
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_1_2_1_5 is 1.4502566423104668
# Model: "model_138"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_139 (InputLayer)      [(None, 72, 13)]          0
#
#  dropout_86 (Dropout)        (None, 72, 13)            0
#
#  gru_46 (GRU)                (None, 48)                9072
#
#  dense_138 (Dense)           (None, 1)                 49
#
# =================================================================
# Total params: 9,121
# Trainable params: 9,121
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_1_2_1_6 is 1.194696872325252
# Model: "model_139"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_140 (InputLayer)      [(None, 72, 13)]          0
#
#  dropout_87 (Dropout)        (None, 72, 13)            0
#
#  gru_47 (GRU)                (None, 48)                9072
#
#  dense_139 (Dense)           (None, 1)                 49
#
# =================================================================
# Total params: 9,121
# Trainable params: 9,121
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_1_2_1_7 is 1.3979807281161256
# Model: "model_140"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_141 (InputLayer)      [(None, 72, 13)]          0
#
#  dropout_88 (Dropout)        (None, 72, 13)            0
#
#  lstm_92 (LSTM)              (None, 72)                24768
#
#  dense_140 (Dense)           (None, 1)                 73
#
# =================================================================
# Total params: 24,841
# Trainable params: 24,841
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_1_2_2_0 is 1.168964495052333
# Model: "model_141"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_142 (InputLayer)      [(None, 72, 13)]          0
#
#  dropout_89 (Dropout)        (None, 72, 13)            0
#
#  lstm_93 (LSTM)              (None, 72)                24768
#
#  dense_141 (Dense)           (None, 1)                 73
#
# =================================================================
# Total params: 24,841
# Trainable params: 24,841
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_1_2_2_1 is 0.4829474838112229
# Model: "model_142"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_143 (InputLayer)      [(None, 72, 13)]          0
#
#  dropout_90 (Dropout)        (None, 72, 13)            0
#
#  lstm_94 (LSTM)              (None, 72)                24768
#
#  dense_142 (Dense)           (None, 1)                 73
#
# =================================================================
# Total params: 24,841
# Trainable params: 24,841
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_1_2_2_2 is 0.7715711463087849
# Model: "model_143"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_144 (InputLayer)      [(None, 72, 13)]          0
#
#  dropout_91 (Dropout)        (None, 72, 13)            0
#
#  lstm_95 (LSTM)              (None, 72)                24768
#
#  dense_143 (Dense)           (None, 1)                 73
#
# =================================================================
# Total params: 24,841
# Trainable params: 24,841
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_1_2_2_3 is 0.7937758020837177
# Model: "model_144"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_145 (InputLayer)      [(None, 72, 13)]          0
#
#  dropout_92 (Dropout)        (None, 72, 13)            0
#
#  lstm_96 (LSTM)              (None, 72)                24768
#
#  dense_144 (Dense)           (None, 1)                 73
#
# =================================================================
# Total params: 24,841
# Trainable params: 24,841
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_1_2_2_4 is 10.413364734343947
# Model: "model_145"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_146 (InputLayer)      [(None, 72, 13)]          0
#
#  dropout_93 (Dropout)        (None, 72, 13)            0
#
#  lstm_97 (LSTM)              (None, 72)                24768
#
#  dense_145 (Dense)           (None, 1)                 73
#
# =================================================================
# Total params: 24,841
# Trainable params: 24,841
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_1_2_2_5 is 1.405184658186317
# Model: "model_146"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_147 (InputLayer)      [(None, 72, 13)]          0
#
#  dropout_94 (Dropout)        (None, 72, 13)            0
#
#  lstm_98 (LSTM)              (None, 72)                24768
#
#  dense_146 (Dense)           (None, 1)                 73
#
# =================================================================
# Total params: 24,841
# Trainable params: 24,841
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_1_2_2_6 is 1.3453689157875859
# Model: "model_147"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_148 (InputLayer)      [(None, 72, 13)]          0
#
#  dropout_95 (Dropout)        (None, 72, 13)            0
#
#  lstm_99 (LSTM)              (None, 72)                24768
#
#  dense_147 (Dense)           (None, 1)                 73
#
# =================================================================
# Total params: 24,841
# Trainable params: 24,841
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_1_2_2_7 is 1.0779014808556069

# %%
# Load in the RMSE data from all trained models

start=time.time()

rmse_array = np.load('rmse_results.npy')

end=time.time()

print("### Points of RMSE data collected from all trained models ###")
print("\nData summary:\n", rmse_array)
print("\nData shape:\n", rmse_array.shape)
print('\nTotal data points:', rmse_array.size)
print(f"\nTime to read: {round(end-start,5)} seconds.")
# Out:
# ### Points of RMSE data collected from all trained models ###
#
# Data summary:
#  [[[[7.94477527e-01 4.47620234e-01 5.18899624e-01 4.99195539e-01
#     7.08252710e-01 2.32530684e-01 5.02077211e-01 8.79202557e-01]
#    [7.11161637e-04 8.93174558e-02 2.02075032e-01 4.01744997e-02
#     1.00175669e-01 2.05583054e-03 2.99586586e-01 1.22869646e-01]
#    [3.71098591e-04 4.74719403e-02 1.72775181e-01 4.87163668e-02
#     7.19697699e-02 1.83785967e-03 2.72671915e-01 9.47294718e-02]]
#
#   [[7.03914211e-01 5.90018951e-01 8.49509116e-01 2.82001590e-01
#     3.32527678e-01 4.01100921e-01 7.03091101e-01 2.84817573e-01]
#    [3.44270875e-01 8.86291712e-02 2.04556072e-01 1.64248826e-01
#     1.16191634e-01 2.25270013e-01 2.85868020e-01 4.42042792e-01]
#    [7.30141801e-04 5.29013199e-02 1.83719471e-01 5.17903780e-02
#     7.71635468e-02 2.49297492e-03 2.65013982e-01 9.94809942e-02]]
#
#   [[3.48509256e-01 1.73467695e-01 4.56292515e-01 4.55426829e-01
#     1.14606708e-01 1.67734523e-01 2.91604576e-01 2.28025347e-01]
#    [4.08613451e-02 1.00000947e-01 1.55577898e-01 1.70733647e-01
#     1.50412043e-01 6.12092430e-03 2.73794527e-01 1.08893359e-01]
#    [3.60933079e-03 4.44756052e-02 1.46174050e-01 5.08284933e-02
#     6.65512515e-02 4.37678091e-03 2.90461614e-01 9.33977202e-02]]]
#
#
#  [[[1.24728316e+00 4.81054071e-01 9.06868327e-01 9.03686156e-01
#     1.03921417e+01 1.43598306e+00 1.04443806e+00 1.27785588e+00]
#    [1.12834452e+00 5.87222372e-01 8.23004769e-01 7.48612936e-01
#     1.03714799e+01 1.48753946e+00 1.50691909e+00 1.23848764e+00]
#    [1.12030106e+00 4.11794144e-01 8.14754831e-01 7.83171943e-01
#     1.04339886e+01 1.28240715e+00 1.37173666e+00 1.09508398e+00]]
#
#   [[1.01751344e+00 5.94146150e-01 7.26401576e-01 7.56706397e-01
#     1.03506577e+01 1.88078771e+00 1.07273157e+00 1.32519269e+00]
#    [1.09252291e+00 4.97151507e-01 8.92201237e-01 7.92715293e-01
#     1.04397897e+01 1.50451428e+00 1.23691116e+00 1.21970590e+00]
#    [1.17843248e+00 4.26826926e-01 8.19523169e-01 8.48807824e-01
#     1.04235446e+01 1.37565307e+00 1.51045074e+00 1.09644610e+00]]
#
#   [[1.03317954e+00 4.94564018e-01 8.41447308e-01 7.68343461e-01
#     1.03798744e+01 1.93809673e+00 1.13048634e+00 1.11358097e+00]
#    [1.17023133e+00 4.31383813e-01 8.07189517e-01 7.53766215e-01
#     1.04048856e+01 1.45025664e+00 1.19469687e+00 1.39798073e+00]
#    [1.16896450e+00 4.82947484e-01 7.71571146e-01 7.93775802e-01
#     1.04133647e+01 1.40518466e+00 1.34536892e+00 1.07790148e+00]]]]
#
# Data shape:
#  (2, 3, 3, 8)
#
# Total data points: 144
#
# Time to read: 0.27618 seconds.

# %%
# Load in all of the different data files
df_0 = pd.read_csv("merged_data_normalized_v2.csv").fillna(0)
df_1 = pd.read_csv("merged_data_v2.csv").fillna(0)
df_2 = pd.read_csv("merged_data_normalized.csv").fillna(0)
df_3 = pd.read_csv("merged_data.csv").fillna(0)
df_4 = pd.read_csv("eia_data_normalized.csv").fillna(0)
df_5 = pd.read_csv("eia_data.csv").fillna(0)

dfs = [df_0, df_1, df_2, df_3, df_4, df_5]

# %%
# Create a list of the different generation types
gen_types = list(df_0.columns[1:9])
for gen_type in gen_types:
  idx = gen_types.index(gen_type)
  gen_type = gen_type.split('_')
  gen_type = gen_type[0]
  gen_types[idx] = gen_type
print(gen_types)
# Out:
# ['coal', 'hydro', 'ng', 'nuclear', 'other', 'petrol', 'solar', 'wind']

# %%
# Manually create the best models dict from previously run instances of code
best_models_dict = {0: [0,0,2,0], 1: [0,2,2,1], 2:[0,2,2,2], 3:[0,0,1,3], 4:[0,2,2,4], 5:[0,0,2,5], 6:[0,1,2,6], 7:[0,2,2,7]}

# %%
# Generate the set of prediction and actual values only for the best models (lowest RMSEs), so that they can be graphed and visualized
# Store these values in a dictionary to be accessed later - and then converted to csv format

test_predictions = {}
test_true_results = {}

for h in range(8):
  i, j, k = best_models_dict[h][0:3]

  print('i =', i)
  print('j =', j)
  print('k =', k)
  print('h =', h)

  path_checkpoint = "TrainedModels/model_checkpoint_" + str(i) + "_" + str(j) + "_" + str(k) + "_" + str(h) + ".h5"
  df = select_input_data(i, j)
  dataset_train, dataset_test = split_training_data(df, i, h)
  model = create_model(df, designs[k], dataset_train)
  model.load_weights(path_checkpoint)
  model.summary()
  # Predictions on validation set
  test_predictions[h] = []
  test_true_results[h] = []

  for x, y in dataset_test.__iter__():
    test_predictions[h].append(model.predict(x))
    test_true_results[h].append(y)

  test_predictions[h] = np.array([item for sublist in test_predictions[h] for item in sublist])
  test_true_results[h] = np.array([item for sublist in test_true_results[h] for item in sublist])

  rmse = np.sqrt(np.mean((test_predictions[h] - test_true_results[h])**2))
  print("RMSE for model_" + str(i) + "_" + str(j) + "_" + str(k) + "_" + str(h) + " is " + str(rmse))
  rmse_arr[i, j, k, h] = rmse
  print('\n')
# Out:
# i = 0
# j = 0
# k = 2
# h = 0
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 72, 67)]          0
#
#  dropout_3 (Dropout)         (None, 72, 67)            0
#
#  lstm_3 (LSTM)               (None, 72)                40320
#
#  dense_2 (Dense)             (None, 1)                 73
#
# =================================================================
# Total params: 40,393
# Trainable params: 40,393
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_2_0 is 0.00037109859058392165
#
#
# i = 0
# j = 2
# k = 2
# h = 1
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 72, 11)]          0
#
#  dropout_4 (Dropout)         (None, 72, 11)            0
#
#  lstm_4 (LSTM)               (None, 72)                24192
#
#  dense_3 (Dense)             (None, 1)                 73
#
# =================================================================
# Total params: 24,265
# Trainable params: 24,265
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_2_2_1 is 0.044475605214879116
#
#
# i = 0
# j = 2
# k = 2
# h = 2
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 72, 11)]          0
#
#  dropout_5 (Dropout)         (None, 72, 11)            0
#
#  lstm_5 (LSTM)               (None, 72)                24192
#
#  dense_4 (Dense)             (None, 1)                 73
#
# =================================================================
# Total params: 24,265
# Trainable params: 24,265
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_2_2_2 is 0.14617404977200013
#
#
# i = 0
# j = 0
# k = 1
# h = 3
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 72, 67)]          0
#
#  dropout_6 (Dropout)         (None, 72, 67)            0
#
#  gru (GRU)                   (None, 48)                16848
#
#  dense_5 (Dense)             (None, 1)                 49
#
# =================================================================
# Total params: 16,897
# Trainable params: 16,897
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_1_3 is 0.04017449974462984
#
#
# i = 0
# j = 2
# k = 2
# h = 4
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 72, 11)]          0
#
#  dropout_7 (Dropout)         (None, 72, 11)            0
#
#  lstm_6 (LSTM)               (None, 72)                24192
#
#  dense_6 (Dense)             (None, 1)                 73
#
# =================================================================
# Total params: 24,265
# Trainable params: 24,265
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_2_2_4 is 0.06655125150446907
#
#
# i = 0
# j = 0
# k = 2
# h = 5
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 72, 67)]          0
#
#  dropout_8 (Dropout)         (None, 72, 67)            0
#
#  lstm_7 (LSTM)               (None, 72)                40320
#
#  dense_7 (Dense)             (None, 1)                 73
#
# =================================================================
# Total params: 40,393
# Trainable params: 40,393
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_0_2_5 is 0.0018378596711337613
#
#
# i = 0
# j = 1
# k = 2
# h = 6
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 72, 19)]          0
#
#  dropout_9 (Dropout)         (None, 72, 19)            0
#
#  lstm_8 (LSTM)               (None, 72)                26496
#
#  dense_8 (Dense)             (None, 1)                 73
#
# =================================================================
# Total params: 26,569
# Trainable params: 26,569
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_1_2_6 is 0.2650139820525122
#
#
# i = 0
# j = 2
# k = 2
# h = 7
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 72, 11)]          0
#
#  dropout_10 (Dropout)        (None, 72, 11)            0
#
#  lstm_9 (LSTM)               (None, 72)                24192
#
#  dense_9 (Dense)             (None, 1)                 73
#
# =================================================================
# Total params: 24,265
# Trainable params: 24,265
# Non-trainable params: 0
# _________________________________________________________________
# RMSE for model_0_2_2_7 is 0.09339772015528734

# %%
# reference: https://ww2.arb.ca.gov/sites/default/files/classic/fuels/lcfs/fuelpathways/comments/tier2/elec_update.pdf
# (for emissions factors)
# 1 MMBtu = 293.07107 kWh (https://www.inchcalculator.com/convert/million-btu-to-kilowatt-hour/)

coal_factor = 279776 / 293.07107
hydro_factor = 0 / 293.07107
ng_factor = 123600 / 293.07107
nuclear_factor = 0 / 293.07107
  
petrol_factor = 253578 / 293.07107
solar_factor = 0 / 293.07107
wind_factor = 0 / 293.07107

other_factor = statistics.mean([coal_factor, hydro_factor ,ng_factor,  nuclear_factor, petrol_factor, solar_factor, wind_factor])

carbon_equivs = np.array([coal_factor, hydro_factor, ng_factor, nuclear_factor, other_factor, petrol_factor, solar_factor, wind_factor])

# %%
# Concatenate all of the test prediction arrays and test actual arrays together

test_predictions_arr = np.concatenate((test_predictions[0], test_predictions[1], test_predictions[2], test_predictions[3], test_predictions[4], test_predictions[5], test_predictions[6], test_predictions[7]), axis=1)
test_true_results_arr = np.column_stack((test_true_results[0], test_true_results[1], test_true_results[2], test_true_results[3], test_true_results[4], test_true_results[5], test_true_results[6], test_true_results[7]))

# %%
# Create the predicted CO2e values csv file, using the best trained models for each gen type

carbon_predictions_arr = np.dot(test_predictions_arr, carbon_equivs)
carbon_true_results_arr = np.dot(test_true_results_arr, carbon_equivs)

# %%
begin = len(df["DateTime"]) - 5103

# %%
datetime_arr = np.array(df["DateTime"][begin:])

# %%
# Create new csv file with all best test predictions and equivalent CO2e emissions (per kWh)
test_predictions_w_CO2e = np.column_stack((datetime_arr, test_predictions_arr, carbon_predictions_arr ))
pd.DataFrame(test_predictions_w_CO2e).to_csv('best_test_predictions_wCO2e.csv')

test_true_results_w_CO2e = np.column_stack((datetime_arr, test_true_results_arr, carbon_true_results_arr ))
pd.DataFrame(test_true_results_w_CO2e).to_csv('test_true_results_wCO2e.csv')

# %%
df_pred = pd.read_csv('best_test_predictions_wCO2e.csv')
df_true = pd.read_csv('test_true_results_wCO2e.csv')

df_pred.rename(columns = {"0":"DateTime", "1":"Coal", "2":"Hydro", "3":"Natural Gas", "4": "Nuclear", "5":"Other", "6": "Petrol", "7":"Solar", "8":"Wind", "9": "gCO2/kWh"},inplace=True)
df_true.rename(columns = {"0":"DateTime", "1":"Coal", "2":"Hydro", "3":"Natural Gas", "4": "Nuclear", "5":"Other", "6": "Petrol", "7":"Solar", "8":"Wind", "9": "gCO2/kWh"},inplace=True)

# %%
def plot_comparison(output, duration, displacement):
  """

  Takes in the following variables:
  output = the generation type OR carbon emissions in question, which we want to model
  duration = the number of hours in consideration
  displacement = the hour to start graphing within the test set

  Outputs:
  A graph of the predicted versus actual values for a single generation type or carbon emissions for the timeline specified

  """

  if output == "gCO2/kWh":
    chart_title = "Carbon Intensity of the CAISO"
    y_axis_name = "Grams CO2 per kWh"
    true_series_name = "Actual Carbon Intensity (gCO2/kWh)"
    pred_series_name = "Predicted Carbon Intensity (gCO2/kWh)"
  else:
    chart_title = f"{output} Electric Generation in the CAISO"
    y_axis_name = "Fraction of Total Generation"
    true_series_name = f"{output} Actual Generation"
    pred_series_name = f"{output} Predicted Generation"


  start = displacement 
  stop = displacement + duration

  fig = go.Figure()
  fig.add_trace(go.Scatter(x=df_true["DateTime"][start:stop],
                         y=df_true[output][start:stop],
                         mode='lines',
                         name=true_series_name,
                         opacity=0.8,
                         line=dict(color='orange', width=1)
                        ))
  fig.add_trace(go.Scatter(x=df_pred["DateTime"][start:stop],
                         y=df_pred[output][start:stop],
                         mode='lines',
                         name=pred_series_name,
                         opacity=0.8,
                         line=dict(color='blue', width=1)
                        ))

# Change chart background color
  fig.update_layout(dict(plot_bgcolor = 'white'))

# Update axes lines
  fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='lightgrey', 
                 zeroline=True, zerolinewidth=1, zerolinecolor='lightgrey', 
                 showline=True, linewidth=1, linecolor='black',
                 title='Date-Time'
                )

  fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='lightgrey', 
                 zeroline=True, zerolinewidth=1, zerolinecolor='lightgrey', 
                 showline=True, linewidth=1, linecolor='black',
                 title= y_axis_name
                )




# Set figure title
  fig.update_layout(title=dict(text=chart_title, 
                             font=dict(color='black')),
                  legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1)
                 )

  fig.show()

# %%
plot_comparison(output="gCO2/kWh", duration=72, displacement=3999)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e2df6167-a580-4100-880f-d889a5846fea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2df6167-a580-4100-880f-d889a5846fea")) {                    Plotly.newPlot(                        "e2df6167-a580-4100-880f-d889a5846fea",                        [{"line":{"color":"orange","width":1},"mode":"lines","name":"Actual Carbon Intensity (gCO2/kWh)","opacity":0.8,"x":["3/12/2022 0:00","3/12/2022 1:00","3/12/2022 2:00","3/12/2022 3:00","3/12/2022 4:00","3/12/2022 5:00","3/12/2022 6:00","3/12/2022 7:00","3/12/2022 8:00","3/12/2022 9:00","3/12/2022 10:00","3/12/2022 11:00","3/12/2022 12:00","3/12/2022 13:00","3/12/2022 14:00","3/12/2022 15:00","3/12/2022 16:00","3/12/2022 17:00","3/12/2022 18:00","3/12/2022 19:00","3/12/2022 20:00","3/12/2022 21:00","3/12/2022 22:00","3/12/2022 23:00","3/13/2022 0:00","3/13/2022 1:00","3/13/2022 3:00","3/13/2022 4:00","3/13/2022 5:00","3/13/2022 6:00","3/13/2022 7:00","3/13/2022 8:00","3/13/2022 9:00","3/13/2022 10:00","3/13/2022 11:00","3/13/2022 12:00","3/13/2022 13:00","3/13/2022 14:00","3/13/2022 15:00","3/13/2022 16:00","3/13/2022 17:00","3/13/2022 18:00","3/13/2022 19:00","3/13/2022 20:00","3/13/2022 21:00","3/13/2022 22:00","3/13/2022 23:00","3/14/2022 0:00","3/14/2022 1:00","3/14/2022 2:00","3/14/2022 3:00","3/14/2022 4:00","3/14/2022 5:00","3/14/2022 6:00","3/14/2022 7:00","3/14/2022 8:00","3/14/2022 9:00","3/14/2022 10:00","3/14/2022 11:00","3/14/2022 12:00","3/14/2022 13:00","3/14/2022 14:00","3/14/2022 15:00","3/14/2022 16:00","3/14/2022 17:00","3/14/2022 18:00","3/14/2022 19:00","3/14/2022 20:00","3/14/2022 21:00","3/14/2022 22:00","3/14/2022 23:00","3/15/2022 0:00"],"y":[231.04608416645053,233.19777472498197,230.4380788370031,244.45947577367983,241.80929489351604,247.47631291701944,183.9545368121284,101.2744134109996,87.66631479908659,90.92359166919478,82.31258357260968,83.16393394584752,85.38391984926191,79.26347841391119,82.27416962474568,120.26265883848288,181.9948733698504,236.4072218923553,239.5606455473645,244.8726864027662,238.47093868881117,232.7306360321104,219.21653755183095,231.6868154927764,240.27864565405537,235.7932862404048,226.78927614754525,213.7464139351211,196.8914135526317,214.8201184026172,158.24176053993023,76.9147599938638,58.71856112764144,63.73071241092866,66.899751114704,76.47083571298936,71.8556619524765,76.35062616068421,88.47215409685731,126.95547910350696,219.4496543046592,256.10002995716167,264.11235418386985,266.7941713100931,266.30892372578825,263.99115242323694,257.7631728814379,255.9460037533948,259.79311851265385,258.80623826330685,255.71185445708053,255.4384052152206,258.9713027961901,272.52684693981564,185.3235884360229,93.22254042043016,79.06372609310284,74.56284022259662,82.03208029434634,79.72658158368108,76.18563394619703,74.75304459287639,80.56999571504714,119.9855481309509,221.8793649350397,278.6816978496464,279.7745140747611,278.8610410480083,275.73052871861324,274.25947076781944,270.08102252145187,272.19862502775175],"type":"scatter"},{"line":{"color":"blue","width":1},"mode":"lines","name":"Predicted Carbon Intensity (gCO2/kWh)","opacity":0.8,"x":["3/12/2022 0:00","3/12/2022 1:00","3/12/2022 2:00","3/12/2022 3:00","3/12/2022 4:00","3/12/2022 5:00","3/12/2022 6:00","3/12/2022 7:00","3/12/2022 8:00","3/12/2022 9:00","3/12/2022 10:00","3/12/2022 11:00","3/12/2022 12:00","3/12/2022 13:00","3/12/2022 14:00","3/12/2022 15:00","3/12/2022 16:00","3/12/2022 17:00","3/12/2022 18:00","3/12/2022 19:00","3/12/2022 20:00","3/12/2022 21:00","3/12/2022 22:00","3/12/2022 23:00","3/13/2022 0:00","3/13/2022 1:00","3/13/2022 3:00","3/13/2022 4:00","3/13/2022 5:00","3/13/2022 6:00","3/13/2022 7:00","3/13/2022 8:00","3/13/2022 9:00","3/13/2022 10:00","3/13/2022 11:00","3/1 ...
